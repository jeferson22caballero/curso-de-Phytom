# %%
1#ejercicio loveseat
# description 
lovely_loveseat_description ="""
Lovely Loveseat. 
Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. 
Red or white""" 
print(lovely_loveseat_description)

2 #ejercicio 
lovely_loveseat_price = 254.00
print (lovely_loveseat_price)

3 #ejercicio
styling_settee_description ="""
Stylish Settee. 
Faux leather on birch. 
29.50 inches high x 54.75 inches wide x 28 inches deep. 
Black."""
print (styling_settee_description)

4 #ejercicio
style_settee_price = 180.50
print (style_settee_price)

5 #ejercicio
luxury_lamp_description ="""
Luxurious Lamp. 
Glass and iron. 
36 inches tall. 
Brown with cream shade."""
print (luxury_lamp_description)

6 #ejercicio
luxury_lamp_price = 52.15
print (luxury_lamp_price)

7 #ejercicio
sales_tax = 0.088
print (sales_tax)

8 #ejercicio
customer_one_total = 0
print (customer_one_total)

9 #ejercicio
customer_one_itemization ="""
"""
print (customer_one_itemization)

10 #ejercicio
customer_one_total ="""
"""
print (customer_one_total)

11 #ejercicio
customer_one_itemization =lovely_loveseat_description
print (customer_one_itemization)

12 #ejercicio
customer_one_total = luxury_lamp_price
print (customer_one_total)

13 #ejercicio

customer_one_itemization =luxury_lamp_description 
print (customer_one_itemization)

14 #ejercicio
customer_one_tax = customer_one_tax * sales_tax
print (customer)
# Out:
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white
# 254.0
#
# Stylish Settee.
# Faux leather on birch.
# 29.50 inches high x 54.75 inches wide x 28 inches deep.
# Black.
# 180.5
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
# 52.15
# 0.088
# 0
#
#
#
#
#
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white
# 52.15
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 69>()
#      66 print (customer_one_itemization)
#      68 14 #ejercicio
# ---> 69 customer_one_tax = customer_one_tax * sales_tax
#      70 print (customer)
#
# NameError: name 'customer_one_tax' is not defined
